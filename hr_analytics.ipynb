# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("data/hr/human-resources-analytics.zip",compression='zip')

# %%
len(df)
# Out:
# 14999

# %%
len(df.columns)
# Out:
# 10

# %%
df.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# sales                     object
# salary                    object
# dtype: object

# %%
df.isnull().sum()*100/len(df)
# Out:
# satisfaction_level       0.0
# last_evaluation          0.0
# number_project           0.0
# average_montly_hours     0.0
# time_spend_company       0.0
# Work_accident            0.0
# left                     0.0
# promotion_last_5years    0.0
# sales                    0.0
# salary                   0.0
# dtype: float64

# %%
df.describe(include='all')
# Out:
#         satisfaction_level  last_evaluation  number_project  \
# count         14999.000000     14999.000000    14999.000000
# unique                 NaN              NaN             NaN
# top                    NaN              NaN             NaN
# freq                   NaN              NaN             NaN
# mean              0.612834         0.716102        3.803054
# std               0.248631         0.171169        1.232592
# min               0.090000         0.360000        2.000000
# 25%               0.440000         0.560000        3.000000
# 50%               0.640000         0.720000        4.000000
# 75%               0.820000         0.870000        5.000000
# max               1.000000         1.000000        7.000000
#
#         average_montly_hours  time_spend_company  Work_accident          left  \
# count           14999.000000        14999.000000   14999.000000  14999.000000
# unique                   NaN                 NaN            NaN           NaN
# top                      NaN                 NaN            NaN           NaN
# freq                     NaN                 NaN            NaN           NaN
# mean              201.050337            3.498233       0.144610      0.238083
# std                49.943099            1.460136       0.351719      0.425924
# min                96.000000            2.000000       0.000000      0.000000
# 25%               156.000000            3.000000       0.000000      0.000000
# 50%               200.000000            3.000000       0.000000      0.000000
# 75%               245.000000            4.000000       0.000000      0.000000
# max               310.000000           10.000000       1.000000      1.000000
#
#         promotion_last_5years  sales salary
# count            14999.000000  14999  14999
# unique                    NaN     10      3
# top                       NaN  sales    low
# freq                      NaN   4140   7316
# mean                 0.021268    NaN    NaN
# std                  0.144281    NaN    NaN
# min                  0.000000    NaN    NaN
# 25%                  0.000000    NaN    NaN
# 50%                  0.000000    NaN    NaN
# 75%                  0.000000    NaN    NaN
# max                  1.000000    NaN    NaN

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
df.sales.value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: sales, dtype: int64

# %%
df.left.value_counts()*100/len(df)
# Out:
# 0    76.191746
# 1    23.808254
# Name: left, dtype: float64

# %%
df.salary.value_counts()/len(df)
# Out:
# low       0.487766
# medium    0.429762
# high      0.082472
# Name: salary, dtype: float64

# %%
df1 = df[df['left']==0]
df1.salary.value_counts()*100/len(df1)
# Out:
# low       45.012251
# medium    44.880994
# high      10.106755
# Name: salary, dtype: float64

# %%
df1 = df[df['left']==1]
df1.salary.value_counts()*100/len(df1)
# Out:
# low       60.823299
# medium    36.880426
# high       2.296276
# Name: salary, dtype: float64

# %%
salary_map = {'low':1,'medium':2,'high':3}
df['salary_int'] = df.salary.map(salary_map)

# %%
df['number_project'].value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df['satisfaction_level'].plot.kde()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
# box plot of satisfaction_level for each department
df[['sales','satisfaction_level']].boxplot(by='sales',figsize=(16,8))
# Out:
# <AxesSubplot: title={'center': 'satisfaction_level'}, xlabel='[sales]'>

# %%
# heat map of correlation matrix
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn_r', linewidths=0.5)
# Out:
# /tmp/ipykernel_22618/863300587.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='RdYlGn_r', linewidths=0.5)
# <AxesSubplot: >

# %%
df['colors'] = df.sales.apply(lambda x: x.lower()[0])

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary', 'salary_int', 'colors'],
#       dtype='object')

# %%
#sns.FacetGrid?

# %%
#scatter plot of satisfaction_level and last_evaluation for differt departments
# change the hue variables to see how the data is distributed
temp_df = df.copy()
#temp_df = df[df.sales=="IT"].copy()
fg = sns.FacetGrid(data=temp_df, hue='sales', aspect=1.61,height=10,
                   hue_kws={'s':df.salary_int*50})
fg.map(plt.scatter, 'satisfaction_level', 'last_evaluation').add_legend()

# %%
cols = ['sales','satisfaction_level']
df1 = df[df['left']==1]
df_grp = df1[cols].groupby(['sales'])
dx = df_grp.agg([len,np.sum,np.max,np.min,np.mean,np.std])
dx.columns = pd.MultiIndex.droplevel(dx.columns,0)
dx['pct_sat'] = dx['sum']*100/dx['len'].sum()
dx['left'] = 1
dx
# Out:
#               len     sum  amax  amin      mean       std    pct_sat  left
# sales
# IT            273  112.44  0.92  0.09  0.411868  0.271041   3.148698     1
# RandD         121   52.37  0.92  0.09  0.432810  0.282230   1.466536     1
# accounting    204   82.13  0.91  0.09  0.402598  0.256977   2.299916     1
# hr            215   93.18  0.91  0.09  0.433395  0.243090   2.609353     1
# management     91   38.48  0.90  0.09  0.422857  0.270248   1.077569     1
# marketing     203   91.99  0.90  0.09  0.453153  0.249197   2.576029     1
# product_mng   198   95.35  0.91  0.09  0.481566  0.264036   2.670120     1
# sales        1014  453.93  0.92  0.09  0.447663  0.258455  12.711565     1
# support       555  250.25  0.91  0.09  0.450901  0.263695   7.007841     1
# technical     697  301.47  0.92  0.09  0.432525  0.275878   8.442173     1

# %%
cols = ['sales','satisfaction_level']
df1 = df[df['left']==0]
df_grp = df1[cols].groupby(['sales'])
dy = df_grp.agg([len,np.sum,np.max,np.min,np.mean,np.std])
dy.columns = pd.MultiIndex.droplevel(dy.columns,0)
dy['pct_sat'] = dy['sum']*100/dy['len'].sum()
dy['left'] = 0
dy
# Out:
#               len      sum  amax  amin      mean       std    pct_sat  left
# sales
# IT            954   646.02   1.0  0.12  0.677170  0.209040   5.652958     0
# RandD         666   435.43   1.0  0.12  0.653799  0.221831   3.810203     0
# accounting    563   364.38   1.0  0.12  0.647211  0.221350   3.188484     0
# hr            524   349.34   1.0  0.13  0.666679  0.216091   3.056878     0
# management    539   352.97   1.0  0.12  0.654861  0.201581   3.088642     0
# marketing     655   438.77   1.0  0.12  0.669878  0.218826   3.839429     0
# product_mng   704   463.56   1.0  0.13  0.658466  0.220944   4.056353     0
# sales        3126  2089.88   1.0  0.12  0.668548  0.222123  18.287364     0
# support      1674  1127.94   1.0  0.12  0.673799  0.213199   9.869968     0
# technical    2023  1352.01   1.0  0.12  0.668319  0.215489  11.830679     0

# %%
dz = pd.concat([dx,dy],axis=1)
dz.sort_index()
# Out:
#               len     sum  amax  amin      mean       std    pct_sat  left  \
# sales
# IT            273  112.44  0.92  0.09  0.411868  0.271041   3.148698     1
# RandD         121   52.37  0.92  0.09  0.432810  0.282230   1.466536     1
# accounting    204   82.13  0.91  0.09  0.402598  0.256977   2.299916     1
# hr            215   93.18  0.91  0.09  0.433395  0.243090   2.609353     1
# management     91   38.48  0.90  0.09  0.422857  0.270248   1.077569     1
# marketing     203   91.99  0.90  0.09  0.453153  0.249197   2.576029     1
# product_mng   198   95.35  0.91  0.09  0.481566  0.264036   2.670120     1
# sales        1014  453.93  0.92  0.09  0.447663  0.258455  12.711565     1
# support       555  250.25  0.91  0.09  0.450901  0.263695   7.007841     1
# technical     697  301.47  0.92  0.09  0.432525  0.275878   8.442173     1
#
#               len      sum  amax  amin      mean       std    pct_sat  left
# sales
# IT            954   646.02   1.0  0.12  0.677170  0.209040   5.652958     0
# RandD         666   435.43   1.0  0.12  0.653799  0.221831   3.810203     0
# accounting    563   364.38   1.0  0.12  0.647211  0.221350   3.188484     0
# hr            524   349.34   1.0  0.13  0.666679  0.216091   3.056878     0
# management    539   352.97   1.0  0.12  0.654861  0.201581   3.088642     0
# marketing     655   438.77   1.0  0.12  0.669878  0.218826   3.839429     0
# product_mng   704   463.56   1.0  0.13  0.658466  0.220944   4.056353     0
# sales        3126  2089.88   1.0  0.12  0.668548  0.222123  18.287364     0
# support      1674  1127.94   1.0  0.12  0.673799  0.213199   9.869968     0
# technical    2023  1352.01   1.0  0.12  0.668319  0.215489  11.830679     0

# %%
#df.pivot_table(aggfunc=len,index=['sales'])
#df.pivot_table(aggfunc=len,index=['sales'],columns=['left'],values=['satisfaction_level'])
df.pivot_table(aggfunc=np.mean,index=['sales'],columns=['salary','left'],values=['satisfaction_level'])
# Out:
#             satisfaction_level                                          \
# salary                    high                 low              medium
# left                         0         1         0         1         0
# sales
# IT                    0.641013  0.582500  0.681648  0.428314  0.679224
# RandD                 0.607021  0.347500  0.651294  0.470182  0.663387
# accounting            0.635217  0.322000  0.643282  0.393333  0.655064
# hr                    0.735897  0.265000  0.658560  0.476848  0.663678
# management            0.654375  0.420000  0.680496  0.467627  0.639433
# marketing             0.628310  0.423333  0.675833  0.443175  0.674123
# product_mng           0.641935  0.326667  0.661908  0.485810  0.657905
# sales                 0.660039  0.447143  0.669365  0.462999  0.669244
# support               0.662406  0.532500  0.673435  0.432674  0.676084
# technical             0.646705  0.480000  0.668833  0.398386  0.672181
#
#
# salary
# left                1
# sales
# IT           0.375670
# RandD        0.405161
# accounting   0.415800
# hr           0.407863
# management   0.337742
# marketing    0.475588
# product_mng  0.487126
# sales        0.412409
# support      0.491646
# technical    0.472381

# %% [markdown]
# ### Using RandomForest Classifier for predection

# %%
df_final = df.drop(['salary'],axis=1).copy()

# %%
df_final.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# sales                     object
# salary_int                 int64
# colors                    object
# dtype: object

# %%
df_final.sales.value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: sales, dtype: int64

# %%
pd.get_dummies(df_final,columns=['sales']).head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  salary_int  \
# 0                   3              0     1                      0           1
# 1                   6              0     1                      0           2
# 2                   4              0     1                      0           2
# 3                   5              0     1                      0           1
# 4                   3              0     1                      0           1
#
#   colors  sales_IT  sales_RandD  sales_accounting  sales_hr  sales_management  \
# 0      s         0            0                 0         0                 0
# 1      s         0            0                 0         0                 0
# 2      s         0            0                 0         0                 0
# 3      s         0            0                 0         0                 0
# 4      s         0            0                 0         0                 0
#
#    sales_marketing  sales_product_mng  sales_sales  sales_support  \
# 0                0                  0            1              0
# 1                0                  0            1              0
# 2                0                  0            1              0
# 3                0                  0            1              0
# 4                0                  0            1              0
#
#    sales_technical
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
df_final = pd.get_dummies(df_final,columns=['sales'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
y = df_final['left']
X = df_final.drop(['left','colors'],axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X_train.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# promotion_last_5years      int64
# salary_int                 int64
# sales_IT                   uint8
# sales_RandD                uint8
# sales_accounting           uint8
# sales_hr                   uint8
# sales_management           uint8
# sales_marketing            uint8
# sales_product_mng          uint8
# sales_sales                uint8
# sales_support              uint8
# sales_technical            uint8
# dtype: object

# %%
clf = RandomForestClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
my_list = list(zip(list(y_test),list(y_pred)))

# %%
wronng_cls = [pair for pair in list(enumerate(my_list)) if pair[1][0] != pair[1][1]]
wronng_cls[0:10]
# Out:
# [(102, (1, 0)),
#  (114, (1, 0)),
#  (130, (1, 0)),
#  (132, (0, 1)),
#  (320, (1, 0)),
#  (473, (1, 0)),
#  (509, (1, 0)),
#  (571, (0, 1)),
#  (604, (1, 0)),
#  (620, (1, 0))]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7872727272727272

# %%
df_final.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'salary_int', 'colors', 'sales_IT',
#        'sales_RandD', 'sales_accounting', 'sales_hr', 'sales_management',
#        'sales_marketing', 'sales_product_mng', 'sales_sales', 'sales_support',
#        'sales_technical'],
#       dtype='object')

# %%
features = X.columns
importances = clf.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), features) ## removed [indices]
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# ### Using Logistic Regression for predection

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf_lr = LogisticRegression(max_iter=500)

# %%
clf_lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
y_pred = clf_lr.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7872727272727272
